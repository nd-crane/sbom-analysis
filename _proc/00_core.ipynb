# %% [raw]
# ---
# output-file: core.html
# title: Core Functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This page defines all boilerplate functions to be used when analyzing sboms.  To see these functions in action please view the following pages.

# %% [markdown]
# ## Basic Queries
#
# These functions perform basic queries and return metadata about a given knowledge graph

# %%
#| echo: false
#| output: asis
show_doc(show_metadata)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### show_metadata
#
# >      show_metadata (kg:kglab.kglab.KnowledgeGraph, dataframe:bool=False)
#
# Return total number of triples, distict entities, and properties to a pandas dataframe.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | kg | KnowledgeGraph |  | Knowledge graph to query from |
# | dataframe | bool | False | Optionally, return result to dataframe |

# %%
#| echo: false
#| output: asis
show_doc(show_entity_types)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L37){target="_blank" style="float:right; font-size:smaller"}
#
# ### show_entity_types
#
# >      show_entity_types (kg:kglab.kglab.KnowledgeGraph, dataframe:bool=False)
#
# Show counts of entity types
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | kg | KnowledgeGraph |  | Knowledge graph to query from |
# | dataframe | bool | False | Optionally, return result to dataframe |

# %%
#| echo: false
#| output: asis
show_doc(show_top_n_props)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L62){target="_blank" style="float:right; font-size:smaller"}
#
# ### show_top_n_props
#
# >      show_top_n_props (kg:kglab.kglab.KnowledgeGraph, n:int=10,
# >                        dataframe:bool=False)
#
# Display the top N properties from a knowledge graph
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | kg | KnowledgeGraph |  | Knowledge graph to query from |
# | n | int | 10 | Top n results to display |
# | dataframe | bool | False | Optionally, return result to dataframe |

# %%
#| echo: false
#| output: asis
show_doc(show_measures)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L88){target="_blank" style="float:right; font-size:smaller"}
#
# ### show_measures
#
# >      show_measures (kg:kglab.kglab.KnowledgeGraph)
#
# Display number of nodes and edges for knowledge graph
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |

# %% [markdown]
# ## Files
#
# These functions peform queries on a SBOM's files

# %%
#| echo: false
#| output: asis
show_doc(file_schema)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L99){target="_blank" style="float:right; font-size:smaller"}
#
# ### file_schema
#
# >      file_schema (kg:kglab.kglab.KnowledgeGraph)
#
# Display all properties for a file
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |

# %%
#| echo: false
#| output: asis
show_doc(get_files_data)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L116){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_files_data
#
# >      get_files_data (kg:kglab.kglab.KnowledgeGraph)
#
# Return all files and their properties
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |
# | **Returns** | **DataFrame** | **Return result to dataframe** |

# %%
#| echo: false
#| output: asis
show_doc(get_files_graph)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L157){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_files_graph
#
# >      get_files_graph (kg:kglab.kglab.KnowledgeGraph)
#
# Return a subgraph of the files and their properties
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |
# | **Returns** | **KnowledgeGraph** | **Return result to knowledge graph** |

# %% [markdown]
# ## Packages

# %%
#| echo: false
#| output: asis
show_doc(package_schema)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L194){target="_blank" style="float:right; font-size:smaller"}
#
# ### package_schema
#
# >      package_schema (kg:kglab.kglab.KnowledgeGraph)
#
# Return the schema for the package
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |
# | **Returns** | **DataFrame** | **Return result to dataframe** |

# %%
#| echo: false
#| output: asis
show_doc(get_package_data)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L211){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_package_data
#
# >      get_package_data (kg:kglab.kglab.KnowledgeGraph)
#
# Construct a dataframe of package data
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |
# | **Returns** | **DataFrame** | **Return result to dataframe** |

# %%
#| echo: false
#| output: asis
show_doc(get_package_graph)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L284){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_package_graph
#
# >      get_package_graph (kg:kglab.kglab.KnowledgeGraph)
#
# Construct a subgraph of the package data
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |
# | **Returns** | **KnowledgeGraph** | **Return result to knowledge graph** |

# %% [markdown]
# ## Relationships

# %%
#| echo: false
#| output: asis
show_doc(relationship_schema)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L371){target="_blank" style="float:right; font-size:smaller"}
#
# ### relationship_schema
#
# >      relationship_schema (kg:kglab.kglab.KnowledgeGraph)
#
# Return the schema for the relationships
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |
# | **Returns** | **DataFrame** | **Return result to dataframe** |

# %%
#| echo: false
#| output: asis
show_doc(get_relationship_data)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L391){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_relationship_data
#
# >      get_relationship_data (kg:kglab.kglab.KnowledgeGraph)
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |
# | **Returns** | **DataFrame** | **Return result to dataframe** |

# %%
#| echo: false
#| output: asis
show_doc(get_relationship_graph)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L409){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_relationship_graph
#
# >      get_relationship_graph (kg:kglab.kglab.KnowledgeGraph)
#
# Construct a subgraph of the relationship data
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kg | KnowledgeGraph | Knowledge graph to query from |
# | **Returns** | **KnowledgeGraph** | **Return result to knowledge graph** |

# %% [markdown]
# ## Visualization

# %% [markdown]
# Functions to visualize graph results

# %%
#| echo: false
#| output: asis
show_doc(visualize_graph)
# Out:
# ---
#
# [source](https://github.com/nd-crane/sbom-analysis/blob/main/sbom_analysis/core.py#L447){target="_blank" style="float:right; font-size:smaller"}
#
# ### visualize_graph
#
# >      visualize_graph (kg:kglab.kglab.KnowledgeGraph, filename:str='tmp.html',
# >                       VIS_STYLE:str={})
#
# Visualize the knowledge graph
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | kg | KnowledgeGraph |  | Knowledge graph to query from |
# | filename | str | tmp.html | Optional, filename to save graph to |
# | VIS_STYLE | str | {} | Optional, visualization style |
