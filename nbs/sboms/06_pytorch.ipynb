# %%
#| hide
import kglab
import pandas as pd
from sbom_analysis.core import *

# %% [markdown]
# # PyTorch

# %% [markdown]
# SBOM Source: [pytorch/pytorch](https://github.com/pytorch/pytorch) generated using [microsoft/sbom-tool](https://github.com/microsoft/sbom-tool)
#
# RDF Source: Generated using [pyspdxtools](https://github.com/spdx/tools-python)

# %% [markdown]
# ## Generated SBOM

# %% [markdown]
# The `SBOM Tool` is designed to scan the build components path, which typically refers to the source folder, in order to locate project files such as `*.csproj`, `requirements.txt` or `*.lock`. By analyzing these files, the tool determines the components that were were used to build the project. During this process, the `SBOM Tool` uses [`ComponentDetection`](https://github.com/microsoft/component-detection) to perform the scanning of components and their dependencies.
#
# In the pytorch repo the [`ComponentDetection`](https://github.com/microsoft/component-detection) could detect the following project files:
#
# - `./ios/TestApp/Gemfile.lock`
# - `./tools/build/bazel/requirements.txt`
# - `./functorch/docs/requirements.txt`
# - `./caffe2/requirements.txt`
# - `./requirements.txt`
# - `./docs/requirements.txt`
# - `./scripts/release_notes/requirements.txt`
# - `./docs/cpp/requirements.txt`
#
#
# For each project file, a dependency graph is defined, but unfortunately this graph is not being used in the SBOM file generation.
#
# In total, **225 packages** were found: **135 Pip** and **90 ruby** packages.
#
# No files detected. 	**255 relationships** of the type `DEPENDS_ON`, one for each different package.

# %% [markdown]
# ### SBOM Analysis
#
# Let's analyze how accurate and complete the SBOM for this project is.

# %% [markdown]
# First import the KG form of the SBOM as specified in the header above.

# %%
kg = kglab.KnowledgeGraph()
kg.load_rdf("../../sboms/rdf/pytorch.rdf.xml", format="xml")

# %% [markdown]
# ### Basic Metadata

# %% [markdown]
# Let's start by looking at the overall size of the KG

# %%
show_metadata(kg)
# Out:
# Total Triples: 4076
# Distinct Entities: 680
# Distinct Properties: 24

# %%
show_measures(kg)
# Out:
# edges 4076
# nodes 692

# %% [markdown]
# Already this looks small

# %% [markdown]
# ### Packages

# %%
package_schema(kg)
# Out:
#                         property
# 0             spdx:copyrightText
# 1          spdx:downloadLocation
# 2               spdx:externalRef
# 3             spdx:filesAnalyzed
# 4          spdx:licenseConcluded
# 5           spdx:licenseDeclared
# 6      spdx:licenseInfoFromFiles
# 7                      spdx:name
# 8   spdx:packageVerificationCode
# 9              spdx:relationship
# 10                 spdx:supplier
# 11              spdx:versionInfo
# 12                      rdf:type

# %%
packages = get_package_data(kg)
packages
# Out:
#                                                package annotations  \
# 0    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
# 1    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
# 2    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
# 3    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
# 4    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
# ..                                                 ...         ...
# 221  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
# 222  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
# 223  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
# 224  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
# 225  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...
#
#     attributionTexts checksums copyrightText       downloadLocation  \
# 0                                NOASSERTION       spdx:noassertion
# 1                                NOASSERTION  https://rubygems.org/
# 2                                NOASSERTION  https://rubygems.org/
# 3                                NOASSERTION       spdx:noassertion
# 4                                NOASSERTION       spdx:noassertion
# ..               ...       ...           ...                    ...
# 221                              NOASSERTION  https://rubygems.org/
# 222                              NOASSERTION  https://rubygems.org/
# 223                              NOASSERTION       spdx:noassertion
# 224                              NOASSERTION  https://rubygems.org/
# 225                              NOASSERTION       spdx:noassertion
#
#                           externalRefs hasFiles  licenseConcluded  \
# 0                                                spdx:noassertion
# 1    N072d33db8b0640c0a67f046442d71f6e           spdx:noassertion
# 2    N2b4cf4bd658240ea9faa89424f36c4a8           spdx:noassertion
# 3    N15a4af78e7084b20a9c5b2dc81cabd4d           spdx:noassertion
# 4    N68929099a2814d318464ac8f437c2e77           spdx:noassertion
# ..                                 ...      ...               ...
# 221  Nca4704d9fec1409992a888bca8d96405           spdx:noassertion
# 222  Nb4a1fb4ffd11456faef76db1892e9ce8           spdx:noassertion
# 223  N9af52b914e874d928dfc4c169352e544           spdx:noassertion
# 224  Nfd513ea41d344679b39c5f5611158eb6           spdx:noassertion
# 225  N669f898b81934477a464d5c4c90a1d4a           spdx:noassertion
#
#       licenseDeclared licenseInfoFromFiles                         name  \
# 0    spdx:noassertion                                           PyTorch
# 1    spdx:noassertion                       faraday-net_http_persistent
# 2    spdx:noassertion                                       emoji_regex
# 3    spdx:noassertion                                        matplotlib
# 4    spdx:noassertion                                       tensorboard
# ..                ...                  ...                          ...
# 221  spdx:noassertion                                            simctl
# 222  spdx:noassertion                                           nanaimo
# 223  spdx:noassertion                                              tqdm
# 224  spdx:noassertion                                               unf
# 225  spdx:noassertion                                        MarkupSafe
#
#                  packageVerificationCode               supplier versionInfo  \
# 0    _:N5158fb3e1d49434ba603b3e1cac432b9  Organization: pytorch       2.0.1
# 1                                    NaN            NOASSERTION       1.2.0
# 2                                    NaN            NOASSERTION       3.2.3
# 3                                    NaN            NOASSERTION       3.6.0
# 4                                    NaN            NOASSERTION      2.10.0
# ..                                   ...                    ...         ...
# 221                                  NaN            NOASSERTION       1.6.8
# 222                                  NaN            NOASSERTION       0.3.0
# 223                                  NaN            NOASSERTION      4.65.0
# 224                                  NaN            NOASSERTION       0.1.4
# 225                                  NaN            NOASSERTION       2.1.3
#
#                                          relationships
# 0    Na5371014d0744fa889463b66da2a4b13, N3d105ed8f1...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 221
# 222
# 223
# 224
# 225
#
# [226 rows x 16 columns]

# %% [markdown]
# ### Files

# %%
file_schema(kg)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
get_files_data(kg)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# First thing to point out here, is there are no relationships specified with any of these files. It could be important if these files are being used as libraries within the project to specify that as a relationship.

# %% [markdown]
# ### Relationships

# %% [markdown]
# Finally let's look at what relationships are specified in the KG

# %%
rels = get_relationship_data(kg)
rels
# Out:
#                                                element        elementType  \
# 0    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 1    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 2    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 3    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 4    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# ..                                                 ...                ...
# 221  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 222  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 223  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 224  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 225  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...  spdx:SpdxDocument
#
#                     relationshipType  \
# 0    spdx:relationshipType_dependsOn
# 1    spdx:relationshipType_dependsOn
# 2    spdx:relationshipType_dependsOn
# 3    spdx:relationshipType_dependsOn
# 4    spdx:relationshipType_dependsOn
# ..                               ...
# 221  spdx:relationshipType_dependsOn
# 222  spdx:relationshipType_dependsOn
# 223  spdx:relationshipType_dependsOn
# 224  spdx:relationshipType_dependsOn
# 225  spdx:relationshipType_describes
#
#                                         relatedElement relatedElementType
# 0    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 1    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 2    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 3    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 4    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# ..                                                 ...                ...
# 221  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 222  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 223  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 224  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 225  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
#
# [226 rows x 5 columns]

# %%
rels.describe()
# Out:
#                                                   element   elementType  \
# count                                                 226           226
# unique                                                  2             2
# top     <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...  spdx:Package
# freq                                                  225           225
#
#                        relationshipType  \
# count                               226
# unique                                2
# top     spdx:relationshipType_dependsOn
# freq                                225
#
#                                            relatedElement relatedElementType
# count                                                 226                226
# unique                                                226                  1
# top     <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# freq                                                    1                226

# %% [markdown]
# It looks like most relationshiips are of the `spdx:relationshipType_contains` type.  Let's filter those out to see what remains.

# %%
rels[~rels['relationshipType'].str.contains('spdx:relationshipType_contains')]
# Out:
#                                                element        elementType  \
# 0    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 1    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 2    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 3    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 4    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# ..                                                 ...                ...
# 221  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 222  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 223  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 224  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 225  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...  spdx:SpdxDocument
#
#                     relationshipType  \
# 0    spdx:relationshipType_dependsOn
# 1    spdx:relationshipType_dependsOn
# 2    spdx:relationshipType_dependsOn
# 3    spdx:relationshipType_dependsOn
# 4    spdx:relationshipType_dependsOn
# ..                               ...
# 221  spdx:relationshipType_dependsOn
# 222  spdx:relationshipType_dependsOn
# 223  spdx:relationshipType_dependsOn
# 224  spdx:relationshipType_dependsOn
# 225  spdx:relationshipType_describes
#
#                                         relatedElement relatedElementType
# 0    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 1    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 2    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 3    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 4    <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# ..                                                 ...                ...
# 221  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 222  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 223  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 224  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
# 225  <https://spdx.org/spdxdocs/sbom-tool-1.1.2-49b...       spdx:Package
#
# [226 rows x 5 columns]

# %% [markdown]
# **Relationship graph visualization**

# %%
# get the relationship graph to be visualized
graph = visualize_relationship_graph(kg)

# optional: set the physics layout of the network
graph.force_atlas_2based()
graph.set_edge_smooth('dynamic')

# show graph
graph.show("../figs/fig06.relationship_full.html")
# Out:
# ../figs/fig06.relationship_full.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="../figs/fig06.relationship_full.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# The color of the nodes in the graph refer to the element type in the spdx specification:

# %%
display_relationship_graph_legend()
# Out:
#       SPDX Type Node Color
# 0          File     Yellow
# 1       Package       Blue
# 2  SPDXDocument        Red

# %% [markdown]
# ### Other Elements

# %% [markdown]
# Here's what the KG contains other than Packages, Files, and Relationships

# %%
query = """
SELECT DISTINCT ?type
WHERE {
    # ?element rdf:type ?type
}
"""
kg.query_as_df(query)
# Out:
#                            type
# 0             spdx:SpdxDocument
# 1             spdx:Relationship
# 2                  spdx:Package
# 3              spdx:ExternalRef
# 4  spdx:PackageVerificationCode
# 5             spdx:CreationInfo

# %% [markdown]
# This is nothing specific for AI workflows yet
