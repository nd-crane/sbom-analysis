# %%
#| hide
import kglab
import pandas as pd
from sbom_analysis.core import *

# %% [markdown]
# # Frameworks-Getting-Started SBOM

# %% [markdown]
# SBOM Source: [ndcrane/frameworks-getting-started](https://github.com/nd-crane/frameworks-getting-started) generated using [microsoft/sbom-tool](https://github.com/microsoft/sbom-tool)
#
# RDF Source: Generated using [pyspdxtools](https://github.com/spdx/tools-python)
#
# **NOTICE:** For ease of viewing some cell inputs are hidden.  Please view inputs [here](https://github.com/nd-crane/sbom-analysis/blob/main/nbs/spdx_example.ipynb) for further explinations.

# %% [markdown]
# This SBOM was generated with [microsoft/sbom-tool](https://github.com/microsoft/sbom-tool) from the [ndcrane/frameworks-getting-started](https://github.com/nd-crane/frameworks-getting-started) repo.  This page analyzes the performance of the sbom-tool from an extremely simple ML workflow.

# %% [markdown]
# #### Importing Graph
#
# Here we import the graph to be analyzed as an XML with kglab to the variable `kg`.  This will be our main graph throughout the entirety of this notebook and will always be referred to as `kg`.  From it we will query data and create subgraphs for analysis.

# %%
kg = kglab.KnowledgeGraph()
kg.load_rdf("../../sboms/rdf/frameworks-getting-started.rdf.xml", format="xml")

# %% [markdown]
# ## Graph Overview

# %% [markdown]
# First let's get a general overview of the graph we are working with.   Let's visualize it as a whole and look at some metadata.

# %% [markdown]
# Under default settings, orange represnets spdx: elements, red represents ptr: elements and blue represents all others.  These can be changed as wished.
#
# Let's also take a look at basic graph metadata:

# %%
show_metadata(kg)
# Out:
# Total Triples: 48835
# Distinct Entities: 11235
# Distinct Properties: 29

# %%
show_measures(kg)
# Out:
# edges 48835
# nodes 11252

# %% [markdown]
# Here's some more advanced metadata:
#
# First let's look at a count of each entity type to get a general idea of what our graph represents

# %%
show_entity_types(kg)
# Out:
# http://spdx.org/rdf/terms#Checksum : 5306
# http://spdx.org/rdf/terms#Relationship : 2860
# http://spdx.org/rdf/terms#File : 2653
# http://spdx.org/rdf/terms#Package : 207
# http://spdx.org/rdf/terms#ExternalRef : 206
# http://spdx.org/rdf/terms#SpdxDocument : 1
# http://spdx.org/rdf/terms#CreationInfo : 1
# http://spdx.org/rdf/terms#PackageVerificationCode : 1

# %% [markdown]
# We can also view the top 10 properties of all elements:

# %%
show_top_n_props(kg)
# Out:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type : 11235
# http://spdx.org/rdf/terms#checksumValue : 5306
# http://spdx.org/rdf/terms#checksum : 5306
# http://spdx.org/rdf/terms#algorithm : 5306
# http://spdx.org/rdf/terms#copyrightText : 2860
# http://spdx.org/rdf/terms#relationshipType : 2860
# http://spdx.org/rdf/terms#licenseConcluded : 2860
# http://spdx.org/rdf/terms#relatedSpdxElement : 2860
# http://spdx.org/rdf/terms#relationship : 2860
# http://spdx.org/rdf/terms#licenseInfoInFile : 2653

# %% [markdown]
# SPDX schemas generally represent three main items (in addition to project metadata)
#
# 1. Files in the project
# 2. Dependencies (or packages) used in the project
# 3. Relationships between everything
#
# Let's start by examining how files are represented in this KG

# %% [markdown]
# ## Files

# %% [markdown]
# From the graph let's look at all properties that are present for files

# %%
file_schema(kg)
# Out:
#                  property
# 0           spdx:checksum
# 1      spdx:copyrightText
# 2           spdx:fileName
# 3   spdx:licenseConcluded
# 4  spdx:licenseInfoInFile
# 5                rdf:type

# %% [markdown]
# Already we see there is less information included from this generated file compared to the SPDX example sbom

# %% [markdown]
# And also a dataframe of what is present for files

# %%
files = get_files_data(kg)
files.head(5)
# Out:
#                                               fileID  \
# 0  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 1  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 2  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 3  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 4  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
#
#                                             fileName     licenseInFile  \
# 0  ./quarto/quarto-1.2.335/share/deno_std/cache/g...  spdx:noassertion
# 1  ./.git/objects/cf/e2ee6b560afa0ca0a8866a64afa6...  spdx:noassertion
# 2  ./quarto/quarto-1.2.335/share/formats/pdf/pdfj...  spdx:noassertion
# 3  ./quarto/quarto-1.2.335/share/deno_std/cache/d...  spdx:noassertion
# 4  ./quarto/quarto-1.2.335/share/deno_std/cache/g...  spdx:noassertion
#
#   contributors                                   licenseConcluded  \
# 0               http://spdx.org/rdf/terms#noassertion, http://...
# 1               http://spdx.org/rdf/terms#noassertion, http://...
# 2               http://spdx.org/rdf/terms#noassertion, http://...
# 3               http://spdx.org/rdf/terms#noassertion, http://...
# 4               http://spdx.org/rdf/terms#noassertion, http://...
#
#                               checksum
# 0  _:Nc63269a9d9f940f09e60dcb0962d9c1a
# 1  _:Ne386f3ee788f4538bbc99dfdc805636a
# 2  _:N0f1bf711e52d4037a91b8624e939cce6
# 3  _:N8321128f77034949bdd12f89ebb12adf
# 4  _:N8a5f86d58e344d63b6ddf23c067b4e05

# %%
files.describe()
# Out:
#                                                    fileID  \
# count                                                2653
# unique                                               2653
# top     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# freq                                                    1
#
#                                                  fileName     licenseInFile  \
# count                                                2653              2653
# unique                                               2653                 1
# top     ./quarto/quarto-1.2.335/share/deno_std/cache/g...  spdx:noassertion
# freq                                                    1              2653
#
#        contributors                                   licenseConcluded  \
# count          2653                                               2653
# unique            1                                                  1
# top                  http://spdx.org/rdf/terms#noassertion, http://...
# freq           2653                                               2653
#
#                                    checksum
# count                                  2653
# unique                                 2653
# top     _:Nc63269a9d9f940f09e60dcb0962d9c1a
# freq                                      1

# %% [markdown]
# Looking at a basic description of the files dataframe there are a few important items:
#
# 1. All fileIDs and names are unique (this is good)
# 2. All checksum's are unique (this is good)
#     - The checksums point to another node in the KG
# 3. **There is no file license information or contributor information**

# %% [markdown]
# Here's a representation of all files in a graph form:

# %%
subgraph = get_files_graph(kg)

# %%
show_measures(subgraph)
# Out:
# edges 7959
# nodes 2655

# %% [markdown]
# ## Packages

# %%
package_schema(kg)
# Out:
#                         property
# 0             spdx:copyrightText
# 1          spdx:downloadLocation
# 2               spdx:externalRef
# 3             spdx:filesAnalyzed
# 4          spdx:licenseConcluded
# 5           spdx:licenseDeclared
# 6      spdx:licenseInfoFromFiles
# 7                      spdx:name
# 8   spdx:packageVerificationCode
# 9              spdx:relationship
# 10                 spdx:supplier
# 11              spdx:versionInfo
# 12                      rdf:type

# %%
packages = get_package_data(kg)
packages
# Out:
#                                                package annotations  \
# 0    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 1    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 2    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 3    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 4    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# ..                                                 ...         ...
# 202  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 203  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 204  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 205  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 206  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
#
#     attributionTexts checksums copyrightText  downloadLocation  \
# 0                                NOASSERTION  spdx:noassertion
# 1                                NOASSERTION  spdx:noassertion
# 2                                NOASSERTION  spdx:noassertion
# 3                                NOASSERTION  spdx:noassertion
# 4                                NOASSERTION  spdx:noassertion
# ..               ...       ...           ...               ...
# 202                              NOASSERTION  spdx:noassertion
# 203                              NOASSERTION  spdx:noassertion
# 204                              NOASSERTION  spdx:noassertion
# 205                              NOASSERTION  spdx:noassertion
# 206                              NOASSERTION  spdx:noassertion
#
#                           externalRefs hasFiles  licenseConcluded  \
# 0                                                spdx:noassertion
# 1    N62856b0f717a48f992594b918de26914           spdx:noassertion
# 2    Nef311854f4214014a59074bd404d2d0b           spdx:noassertion
# 3    N3936863eac864a87968cdd60a3311a20           spdx:noassertion
# 4    N0f6420517f534c3486e00f9989ae6e19           spdx:noassertion
# ..                                 ...      ...               ...
# 202  N88c7496d1ab34af5ae1fbb3c8cc73b1c           spdx:noassertion
# 203  N5fcb69ed42b644e8a52dbfc94eb6b08d           spdx:noassertion
# 204  Ncd07f9a6fc6e43f292c36aea077a00b6           spdx:noassertion
# 205  N4d00915d97324d12846ed70e4860f304           spdx:noassertion
# 206  N8dd4504ce3d64a5b8f7fb5b069006224           spdx:noassertion
#
#       licenseDeclared licenseInfoFromFiles                name  \
# 0    spdx:noassertion                                     test
# 1    spdx:noassertion                              argon2-cffi
# 2    spdx:noassertion                                    click
# 3    spdx:noassertion                       jupyterlab-widgets
# 4    spdx:noassertion                                   mpmath
# ..                ...                  ...                 ...
# 202  spdx:noassertion                              dvc-objects
# 203  spdx:noassertion                                 requests
# 204  spdx:noassertion                              entrypoints
# 205  spdx:noassertion                                  tornado
# 206  spdx:noassertion                       python-json-logger
#
#                  packageVerificationCode             supplier versionInfo  \
# 0    _:Nbdae0320e9a543f9abbcd2d0375575ed  Organization: NDCRC       1.0.0
# 1                                    NaN          NOASSERTION      21.3.0
# 2                                    NaN          NOASSERTION       8.1.3
# 3                                    NaN          NOASSERTION       3.0.7
# 4                                    NaN          NOASSERTION       1.3.0
# ..                                   ...                  ...         ...
# 202                                  NaN          NOASSERTION      0.22.0
# 203                                  NaN          NOASSERTION      2.30.0
# 204                                  NaN          NOASSERTION         0.4
# 205                                  NaN          NOASSERTION       6.3.2
# 206                                  NaN          NOASSERTION       2.0.7
#
#                                          relationships
# 0    N16e091841fce4e519fd269480cb271f9, N8c855a366f...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 202
# 203
# 204
# 205
# 206
#
# [207 rows x 16 columns]

# %%
packages[packages['name'].str.contains('python')]
# Out:
#                                                package annotations  \
# 28   <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 42   <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 58   <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 99   <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 179  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# 206  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
#
#     attributionTexts checksums copyrightText  downloadLocation  \
# 28                               NOASSERTION  spdx:noassertion
# 42                               NOASSERTION  spdx:noassertion
# 58                               NOASSERTION  spdx:noassertion
# 99                               NOASSERTION  spdx:noassertion
# 179                              NOASSERTION  spdx:noassertion
# 206                              NOASSERTION  spdx:noassertion
#
#                           externalRefs hasFiles  licenseConcluded  \
# 28   Nb8b58c02aec8464e889e5d288274ceea           spdx:noassertion
# 42   Nbf6fef54fe684ecb816361be6f1db245           spdx:noassertion
# 58   N0677aaed34ef45d6ac08b3dc62630642           spdx:noassertion
# 99   Nfacdd7bb5da34df0b41c24fc32e16144           spdx:noassertion
# 179  N8a33454ef54044eca6fa50dc0d527c59           spdx:noassertion
# 206  N8dd4504ce3d64a5b8f7fb5b069006224           spdx:noassertion
#
#       licenseDeclared licenseInfoFromFiles                    name  \
# 28   spdx:noassertion                                      ipython
# 42   spdx:noassertion                                    gitpython
# 58   spdx:noassertion                              python-dateutil
# 99   spdx:noassertion                             ipython-genutils
# 179  spdx:noassertion                       antlr4-python3-runtime
# 206  spdx:noassertion                           python-json-logger
#
#     packageVerificationCode     supplier versionInfo relationships
# 28                      NaN  NOASSERTION      8.13.2
# 42                      NaN  NOASSERTION      3.1.31
# 58                      NaN  NOASSERTION       2.8.2
# 99                      NaN  NOASSERTION       0.2.0
# 179                     NaN  NOASSERTION       4.9.3
# 206                     NaN  NOASSERTION       2.0.7

# %%
packages.describe()
# Out:
#                                                   package annotations  \
# count                                                 207         207
# unique                                                207           1
# top     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...
# freq                                                    1         207
#
#        attributionTexts checksums copyrightText  downloadLocation  \
# count               207       207           207               207
# unique                1         1             1                 1
# top                                 NOASSERTION  spdx:noassertion
# freq                207       207           207               207
#
#        externalRefs hasFiles  licenseConcluded   licenseDeclared  \
# count           207      207               207               207
# unique          207        1                 1                 1
# top                           spdx:noassertion  spdx:noassertion
# freq              1      207               207               207
#
#        licenseInfoFromFiles  name              packageVerificationCode  \
# count                   207   207                                    1
# unique                    1   207                                    1
# top                          test  _:Nbdae0320e9a543f9abbcd2d0375575ed
# freq                    207     1                                    1
#
#            supplier versionInfo relationships
# count           207         207           207
# unique            2         186             2
# top     NOASSERTION       1.0.0
# freq            206           3           206

# %% [markdown]
# Here we see we are missing even more information then the files section.

# %% [markdown]
# ## Relationships

# %%
relationship_schema(kg)
# Out:
#                   property
# 0                 rdf:type
# 1    spdx:relationshipType
# 2  spdx:relatedSpdxElement

# %%
rels = get_relationship_data(kg)
rels
# Out:
#                                                 element        elementType  \
# 0     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
# 1     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
# 2     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
# 3     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
# 4     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
# ...                                                 ...                ...
# 2855  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
# 2856  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
# 2857  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
# 2858  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
# 2859  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...  spdx:SpdxDocument
#
#                      relationshipType  \
# 0      spdx:relationshipType_contains
# 1      spdx:relationshipType_contains
# 2      spdx:relationshipType_contains
# 3      spdx:relationshipType_contains
# 4      spdx:relationshipType_contains
# ...                               ...
# 2855   spdx:relationshipType_contains
# 2856   spdx:relationshipType_contains
# 2857   spdx:relationshipType_contains
# 2858   spdx:relationshipType_contains
# 2859  spdx:relationshipType_describes
#
#                                          relatedElement relatedElementType
# 0     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# 1     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# 2     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# 3     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# 4     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# ...                                                 ...                ...
# 2855  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# 2856  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# 2857  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# 2858  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# 2859  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...       spdx:Package
#
# [2860 rows x 5 columns]

# %%
rels.describe()
# Out:
#                                                   element   elementType  \
# count                                                2860          2860
# unique                                                  2             2
# top     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...  spdx:Package
# freq                                                 2859          2859
#
#                       relationshipType  \
# count                             2860
# unique                               3
# top     spdx:relationshipType_contains
# freq                              2653
#
#                                            relatedElement relatedElementType
# count                                                2860               2860
# unique                                               2860                  2
# top     <https://spdx.org/spdxdocs/sbom-tool-1.1.1-098...          spdx:File
# freq                                                    1               2653

# %% [markdown]
# Lastly our relationshipsare only limited to 3 types and are mostly between Packages and Files

# %%
subgraph = get_relationship_graph(kg)

# %%
show_measures(subgraph)
# Out:
# edges 11441
# nodes 5727

# %% [markdown]
# **Relationship graph visualization**
#
# That relationship graph has a large number of nodes, making it difficult to load the visualization. To make the visualization possible, we can exclude nodes of the type `SPDX:File`. This can be achieved by passing the `hideTypeFile=True` flag to the `visualize_relationship_graph()` function, as shown below:

# %%
# get the relationship graph to be visualized
graph = visualize_relationship_graph(kg, hideTypeFile=True)

# optional: set the physics layout of the network
graph.force_atlas_2based()
graph.set_edge_smooth('dynamic')

# show graph
graph.show("../figs/fig02.relationship.html")
# Out:
# ../figs/fig02.relationship.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="../figs/fig02.relationship.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# The color of the nodes in the graph refer to the element type in the spdx specification:

# %%
display_relationship_graph_legend()
# Out:
#       SPDX Type Node Color
# 0          File     Yellow
# 1       Package       Blue
# 2  SPDXDocument        Red
