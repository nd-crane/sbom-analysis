# %%
#| hide
import kglab
import pandas as pd
from sbom_analysis.core import *

# %% [markdown]
# # Hugging Face Model

# %% [markdown]
# We've established the [microsoft/sbom-tool](https://github.com/microsoft/sbom-tool) looks in the `requirements.txt` for all python dependencies that are not part of `stdlib`, but what if the packages in `requirements.txt` are for C/C++ based projects (like the `llama.cpp` project from the last page)?

# %% [markdown]
# SBOM Source: [TheBloke/text-generation-webui](https://github.com/TheBloke/text-generation-webui) generated using [microsoft/sbom-tool](https://github.com/microsoft/sbom-tool)
#
# RDF Source: Generated using [pyspdxtools](https://github.com/spdx/tools-python)

# %% [markdown]
# ## text-generation-webui Overview

# %% [markdown]
# This repo is a UI for running LLMs like `llama.cpp`.

# %% [markdown]
# It has a number of dependencies, both python and C/C++ based.  Let's look at `requirements.txt`
#
# ```txt
# colorama
# datasets
# flexgen==0.1.7
# gradio_client==0.2.5
# gradio==3.31.0
# markdown
# numpy
# pandas
# Pillow>=9.5.0
# pyyaml
# requests
# safetensors==0.3.1
# sentencepiece
# tqdm
# scipy
# git+https://github.com/huggingface/peft@3714aa2fff158fdfa637b2b65952580801d890b2
# git+https://github.com/huggingface/transformers@e45e756d22206ca8fa9fb057c8c3d8fa79bf81c6
# git+https://github.com/huggingface/accelerate@0226f750257b3bf2cadc4f189f9eef0c764a0467
# bitsandbytes==0.39.0; platform_system != "Windows"
# https://github.com/jllllll/bitsandbytes-windows-webui/raw/main/bitsandbytes-0.39.0-py3-none-any.whl; platform_system == "Windows"
# llama-cpp-python==0.1.53; platform_system != "Windows"
# https://github.com/abetlen/llama-cpp-python/releases/download/v0.1.53/llama_cpp_python-0.1.53-cp310-cp310-win_amd64.whl; platform_system == "Windows"
# ```

# %% [markdown]
# ## SBOM Representation

# %% [markdown]
# Let's see how the sbom knowledge graph reflects this

# %%
kg = kglab.KnowledgeGraph()
kg.load_rdf("sboms/rdf/text-generation-ui.rdf.xml", format="xml")

# %% [markdown]
# ### Packages

# %%
package_schema(kg)
# Out:
#                         property
# 0             spdx:copyrightText
# 1          spdx:downloadLocation
# 2               spdx:externalRef
# 3             spdx:filesAnalyzed
# 4          spdx:licenseConcluded
# 5           spdx:licenseDeclared
# 6      spdx:licenseInfoFromFiles
# 7                      spdx:name
# 8   spdx:packageVerificationCode
# 9              spdx:relationship
# 10                 spdx:supplier
# 11              spdx:versionInfo
# 12                      rdf:type

# %%
packages = get_package_data(kg)
packages
# Out:
#                                                package annotations  \
# 0    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 1    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 2    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 3    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 4    <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# ..                                                 ...         ...
# 141  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 142  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 143  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 144  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 145  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
#
#     attributionTexts checksums copyrightText  downloadLocation  \
# 0                                NOASSERTION  spdx:noassertion
# 1                                NOASSERTION  spdx:noassertion
# 2                                NOASSERTION  spdx:noassertion
# 3                                NOASSERTION  spdx:noassertion
# 4                                NOASSERTION  spdx:noassertion
# ..               ...       ...           ...               ...
# 141                              NOASSERTION  spdx:noassertion
# 142                              NOASSERTION  spdx:noassertion
# 143                              NOASSERTION  spdx:noassertion
# 144                              NOASSERTION  spdx:noassertion
# 145                              NOASSERTION  spdx:noassertion
#
#                           externalRefs hasFiles  licenseConcluded  \
# 0                                                spdx:noassertion
# 1    Nbcbc00ea6ae94cd899f348b26fad8982           spdx:noassertion
# 2    N979f5bc89897463da80aa7cb6bfcf1de           spdx:noassertion
# 3    N09327a3a6dde4e18a1d755ea4cff6e62           spdx:noassertion
# 4    N003a8eed36254591aa0be68cd09d8295           spdx:noassertion
# ..                                 ...      ...               ...
# 141  N1b12d8d0472441e2a42b49fa6f10f92e           spdx:noassertion
# 142  N01f19f5277e84c15b19d47832efb7979           spdx:noassertion
# 143  Nab90bc175481420e87f22cfbed6a39ed           spdx:noassertion
# 144  Na1801ad388a840a7b04892a56aebb6f5           spdx:noassertion
# 145  Na4ca1116a40c4040920f38250c0b79cd           spdx:noassertion
#
#       licenseDeclared licenseInfoFromFiles                      name  \
# 0    spdx:noassertion                          text-generation-webui
# 1    spdx:noassertion                             importlib-metadata
# 2    spdx:noassertion                            importlib-resources
# 3    spdx:noassertion                                      traitlets
# 4    spdx:noassertion                                          numpy
# ..                ...                  ...                       ...
# 141  spdx:noassertion                       nvidia-cuda-runtime-cu11
# 142  spdx:noassertion                                        scandir
# 143  spdx:noassertion                               nvidia-nvtx-cu11
# 144  spdx:noassertion                                      pycparser
# 145  spdx:noassertion                                    pickleshare
#
#                  packageVerificationCode                supplier versionInfo  \
# 0    _:N9b83ea76b5f748638716680397fdcca3  Organization: TheBloke       0.1.0
# 1                                    NaN             NOASSERTION       6.6.0
# 2                                    NaN             NOASSERTION      5.12.0
# 3                                    NaN             NOASSERTION       5.9.0
# 4                                    NaN             NOASSERTION      1.24.3
# ..                                   ...                     ...         ...
# 141                                  NaN             NOASSERTION     11.7.99
# 142                                  NaN             NOASSERTION      1.10.0
# 143                                  NaN             NOASSERTION     11.7.91
# 144                                  NaN             NOASSERTION        2.21
# 145                                  NaN             NOASSERTION       0.7.5
#
#                                          relationships
# 0    N6c8d9472f823447db6751b0eae712bfa, N322eff8e6e...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 141
# 142
# 143
# 144
# 145
#
# [146 rows x 16 columns]

# %% [markdown]
# Let's see if anything with `llama` or `.cpp` is in this knowledge graph

# %%
packages[packages['name'].str.contains('llama')]
# Out:
#                                                package annotations  \
# 129  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
#
#     attributionTexts checksums copyrightText  downloadLocation  \
# 129                              NOASSERTION  spdx:noassertion
#
#                           externalRefs hasFiles  licenseConcluded  \
# 129  N5cc03db56b2d4b6ca9c3794038353c49           spdx:noassertion
#
#       licenseDeclared licenseInfoFromFiles              name  \
# 129  spdx:noassertion                       llama-cpp-python
#
#     packageVerificationCode     supplier versionInfo relationships
# 129                     NaN  NOASSERTION      0.1.53

# %% [markdown]
# Ok, there's a `llama-cpp-python` package.  Looking at the `requirements.txt` this looks like it is imported from `pypi`.

# %% [markdown]
# What about `huggingface` packages, specifically the ones refrenced with git?

# %%
packages[packages['name'].str.contains('huggingface')]
# Out:
#                                                package annotations  \
# 15   <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 18   <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 75   <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
# 108  <https://spdx.org/spdxdocs/sbom-tool-1.1.1-594...
#
#     attributionTexts checksums copyrightText  \
# 15                               NOASSERTION
# 18                               NOASSERTION
# 75                               NOASSERTION
# 108                              NOASSERTION
#
#                                 downloadLocation  \
# 15   https://github.com/huggingface/transformers
# 18                              spdx:noassertion
# 75           https://github.com/huggingface/peft
# 108    https://github.com/huggingface/accelerate
#
#                           externalRefs hasFiles  licenseConcluded  \
# 15                                               spdx:noassertion
# 18   Ne49bb867b3b543a4960ce10309768931           spdx:noassertion
# 75                                               spdx:noassertion
# 108                                              spdx:noassertion
#
#       licenseDeclared licenseInfoFromFiles  \
# 15   spdx:noassertion
# 18   spdx:noassertion
# 75   spdx:noassertion
# 108  spdx:noassertion
#
#                                                   name  \
# 15   https://github.com/huggingface/transformers : ...
# 18                                     huggingface-hub
# 75   https://github.com/huggingface/peft : 3714aa2f...
# 108  https://github.com/huggingface/accelerate : 02...
#
#     packageVerificationCode     supplier versionInfo relationships
# 15                      NaN  NOASSERTION         NaN
# 18                      NaN  NOASSERTION      0.15.1
# 75                      NaN  NOASSERTION         NaN
# 108                     NaN  NOASSERTION         NaN

# %% [markdown]
# That's good, it includes those packages
