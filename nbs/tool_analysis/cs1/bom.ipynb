# %%
#| hide
import kglab
import pandas as pd
from sbom_analysis.core import *
import pandas as pd

pd.set_option("display.precision", 2)
#pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # [Bom](https://github.com/kubernetes-sigs/bom)

# %% [markdown]
# On this page, we will analyze the SBOM generated by the [bom](https://github.com/kubernetes-sigs/bom) tool for the [PyTorch](https://github.com/pytorch/pytorch) GitHub Repository. The overall analysis for `bom` is available [here](../../tool_analysis/tools_overall_analysis.qmd#bom).
#
#
# The SPDX SBOM was generated in the JSON format and converted to RDF/XML using [pyspdxtools](https://github.com/spdx/tools-python).
# It is a valid spdx file and can be validated using the [spdx online validator](https://tools.spdx.org/app/validate/).

# %% [markdown]
# ## SBOM size

# %%
# Note: xml file cannot be loaded correctly

print("Files:", 12068)
print("Packages:", 1)
print("relationships:", 12068)
# Out:
# Files: 12068
# Packages: 1
# relationships: 12068

# %% [markdown]
# ## Is this SBOM NTIA minimum element conformant? False

# %% [markdown]
# | Individual elements                        | Status |
# |-------------------------------------------|--------|
# | All component names provided?              | True   |
# | All component versions provided?           | True  |
# | All component identifiers provided?        | True   |
# | All component suppliers provided?          | False  |
# | SBOM author name provided?                 | True   |
# | SBOM creation timestamp provided?          | True   |
# | Dependency relationships provided?         | True   |
#
#
#
# **Components missing an supplier**: pytorch
#
# Source: [ntia_checker](https://tools.spdx.org/app/ntia_checker/)

# %% [markdown]
# ## Quality Score

# %%
dir_qs = "../../../data/tools_cs1/sbomqs/"
sbomqs_df, feature_qscores = sbomqs_scores(dir_qs)
#display_qscores_with_descriptions(feature_qscores, tool_list=['sbom4python'])
display_qscores_with_descriptions(feature_qscores, tool_list=['bom'])
# Out:
# <h2>Tool: bom (avg score: 7.27)</h2>
# <h3>Category: Structural (avg score: 10.00)
#                  feature  score  \
# 0              sbom_spec   10.0
# 1      sbom_spec_version   10.0
# 2  sbom_spec_file_format   10.0
# 3          sbom_parsable   10.0
#
#                                          description tool
# 0  provided sbom is in a supported sbom format of...  bom
# 1  provided sbom should be in supported spec vers...  bom
# 2  provided sbom should be in supported file form...  bom
# 3                          provided sbom is parsable  bom
# <hr>
# <h3>Category: NTIA-minimum-elements (avg score: 7.14)
#                     feature  score                   description tool
# 4        comp_with_supplier    0.0       0/1 have supplier names  bom
# 5            comp_with_name   10.0                1/1 have names  bom
# 6         comp_with_version    0.0             0/1 have versions  bom
# 7        comp_with_uniq_ids   10.0          1/1 have unique ID's  bom
# ...

# %% [markdown]
# ## Dependencies

# %% [markdown]
# The relationship graph cannot be viewed because the rdf/xml file cannot be loaded correctly.
#
# The sbom file contains onle one package which is the pytorch package itself and it contains all the 12068 files
# detected.
